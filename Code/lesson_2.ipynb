# %%
print(1, 2, 3, 4, 5, sep=',')
print('台北', '台中', '高雄', sep=' -> ')
# Out:
# 1,2,3,4,5
# 台北 -> 台中 -> 高雄

# %% [markdown]
# 1. 三個地區的溫度 (22, 23, 24)<div>
# 2. 2026/5/15

# %%
print(123)
print(456)
# Out:
# 123
# 456

# %%
input('請輸入你的名字：')
# Out:
# 'ying'

# %%
print(input('請輸入你的名字：'))
# Out:
# ying

# %%
name = input('請輸入你的名字：')

# %%
print('早安', name)
# Out:
# 早安 Ying

# %% [markdown]
# 1990.12.31 <div>
# 1990 <div>
# 12 <div>
# 31

# %% [markdown]
# 25/30/40 -> 3 temps

# %%
year, month, day = input('請輸入你的生日（格式：年.月.日）：').split('.')
print(year)
print(month)
print(day)
# Out:
# 1990
# 12
# 31

# %%
temp1, temp2, temp3 = input('請輸入三個數字（格式：數字1/數字2/數字3）：').split('/')
print(temp1)
print(temp2)
print(temp3)
# Out:
# 25
# 35
# 40

# %%
data = input().split()
print(data)
# Out:
# ['小明', '13', '台北']

# %% [markdown]
# case1： 三明治 -> 麵包、麵包、肉片 <div>
# case2: 三明治

# %%
data2 = input()
print(data2)
# Out:
# 小明 13 台北

# %%
name, age, city = input('請輸入名字 年齡 城市：').split()
print(name, age, city)
# Out:
# 小明 13 台北

# %%
print(name)
# Out:
# ying

# %%
print(age)
# Out:
# 26

# %%
print(city)
# Out:
# taichung

# %% [markdown]
# # Variable

# %%
name = "小明"

# %%
print(name)
# Out:
# 小明

# %%
name = "小華"
print(name)
# Out:
# 小華

# %%
drawer = "珍奶"
print(drawer)
# Out:
# 珍奶

# %%
x = 10 # 定義變數 x 的值為 10
print(x + 10) # 輸出 x 加上 10 的結果
# Out:
# 20

# %%
print(x)
# Out:
# 10

# %%
x = x + 10 
print(x)
# Out:
# 20

# %%
print(5.0 - 5)
# Out:
# 0.0

# %% [markdown]
# 學校： 禮拜 一 ～ 五
# 休息： 禮拜 六 日
#
# 去學校 = 1 (True)； 不去學校 = 0 (False)
# 一：1 -> True
# 。。。。
# 五：1 -> True
# 六：0 -> False
# 日：0

# %% [markdown]
# 食物 ->  有 、 沒有
#
# 今天： 有 （東西） "hello", "False"
# 明天： 沒有 （沒有東西）""

# %%
x = true

# %%
list1 = [1, 2, 3, "4", 5.0]
print(list1)
# Out:
# [1, 2, 3, '4', 5.0]

# %%
x = 20
print(type(list1))
# Out:
# <class 'list'>

# %%
temp = '28' # float -> 28.0; int -> 28
print(type(temp))
print(2 * float(temp))
print(2 * int(temp))
print(type(2 * float(temp)))
print(type(2 * int(temp)))
# Out:
# <class 'str'>
# 56.0
# 56
# <class 'float'>
# <class 'int'>

# %%
selection = 0.01
print(bool(selection))
selection_2 = 0
print(bool(selection_2))
# Out:
# True
# False

# %%
selection_bool = True
print(selection_bool)
selection_2_bool = False
print(selection_2_bool)
# Out:
# True
# False

# %%
print(str(selection_bool))
print(str(selection_2_bool))
# Out:
# True
# False

# %%
selection_str = "0.01"
print(bool(selection_str))
selection_2_str = ""
print(bool(selection_2_str))
# Out:
# True
# False

# %%
price = 60
count = '2'
total = price * int(count)
print(total)
# Out:
# 120

# %% [markdown]
# 建立 name 變數，放入自己的英文名字，並印出來。
# 建立 age 變數，放入自己的年齡，並印出 age + 1。
# 建立 price = 45、count = "3"，把 count 轉成整數後計算總價。
# 建立一個串列 intro，放入姓名、年齡、是否喜歡 Python，並印出 intro。
# 使用 type() 檢查 10、10.0、"10"、True、[10] 的型態。

# %%
Name1, Name2, Name3 = input('請輸入你的名字：').split()
intro = [Name1, Name2, Name3, 26, True]
print(intro)
# Out:
# ['Ying', 'Huan', 'Ming', 26, True]
