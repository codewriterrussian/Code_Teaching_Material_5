# %% [markdown]
# # Lesson 6：Conditional Expressions 條件判斷測驗 Notebook
#
# 這份 notebook 是給學生練習 `if`、`elif`、`else` 用的。題目已避開 Lesson 6 講義中直接出現過的範例，讓學生練習把觀念轉移到新情境。
#
# ## 使用方式
#
# 1. 先執行「自動檢查工具」cell。
# 2. 閱讀每一題的題目。
# 3. 只修改 `# TODO` 附近的答案。
# 4. 每完成一題，就執行該題下面的「檢查」cell。
# 5. 最後執行「總檢查」cell。
#
# 注意：檢查 cell 只會告訴你通過或未通過，不會直接顯示正確答案。

# %%
# === 自動檢查工具：請先執行這個 cell，不要修改 ===
import json
import base64

_HIDDEN_CASES_TEXT = """..."""
_HIDDEN_CASES = json.loads(base64.b64decode(_HIDDEN_CASES_TEXT).decode("utf-8"))

def _normalize_args(args):
    return tuple(args)

def run_hidden_cases(question_id, func):
    print(f"\n=== 檢查 {question_id} ===")
    cases = _HIDDEN_CASES[question_id]
    passed = 0
    for i, case in enumerate(cases, start=1):
        args = _normalize_args(case["args"])
        expected = case["expected"]
        try:
            actual = func(*args)
            if actual == expected:
                print(f"✅ {question_id}-{i} 通過")
                passed += 1
            else:
                print(f"❌ {question_id}-{i} 未通過")
                print("你的輸出：", repr(actual))
                print("請再檢查題目要求、空白、換行、型態 int/str/bool 是否正確。")
        except Exception as e:
            print(f"❌ {question_id}-{i} 執行時發生錯誤")
            print(type(e).__name__ + ":", e)
    print(f"結果：{passed}/{len(cases)} 通過")
    return passed == len(cases)

def final_check(results):
    passed = sum(1 for x in results if x)
    total = len(results)
    print(f"\n=== 總檢查 ===")
    print(f"通過題數：{passed}/{total}")
    if passed == total:
        print("🎉 全部通過！")
    else:
        print("還有題目需要修改，請回去檢查未通過的題目。")

# %% [markdown]
# ## 先學會怎麼填答案：`def` 函式作答方式
#
# 這份練習不是讓你直接使用 `input()`，而是讓你把答案寫在一個「函式 function」裡。
#
# 請注意：
#
# 1. `def ...:` 這一行不要刪掉。
# 2. 括號裡的變數是題目給你的資料，可以直接拿來用。
# 3. `return None` 代表「還沒寫答案」，你要把 `None` 換成你的答案。
# 4. 這份練習要用 `return`，不是用 `print()`。

# %%
# 範例：這不是正式題目，只是教你怎麼填答案

def example_weather(is_sunny):
    if is_sunny:
        return "sunny"
    else:
        return "not sunny"

print(example_weather(True))
print(example_weather(False))

# %% [markdown]
# ## Q1. 電影票分類
#
# 請完成函式：依照 `age` 回傳電影票種類。`age < 6` 回傳 `"free"`；`age <= 12` 回傳 `"child"`；其他回傳 `"adult"`。
#
# 請完成下面的函式。

# %%
def q1_movie_ticket(age):
    # TODO: 依照年齡回傳 "free"、"child" 或 "adult"
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q1_ok = run_hidden_cases("Q1", q1_movie_ticket)

# %% [markdown]
# ## Q2. 購物運費判斷
#
# 請完成函式：如果 `total >= 1000`，回傳 `"free shipping"`；否則回傳 `"shipping fee"`。
#
# 請完成下面的函式。

# %%
def q2_shipping_fee(total):
    # TODO: 判斷是否免運
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q2_ok = run_hidden_cases("Q2", q2_shipping_fee)

# %% [markdown]
# ## Q3. 比較兩個數字
#
# 請完成函式：如果 `a > b`，回傳 `"a bigger"`；如果 `a < b`，回傳 `"b bigger"`；否則回傳 `"same"`。
#
# 請完成下面的函式。

# %%
def q3_compare_numbers(a, b):
    # TODO: 比較 a 和 b 的大小
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q3_ok = run_hidden_cases("Q3", q3_compare_numbers)

# %% [markdown]
# ## Q4. 判斷是否為閏年
#
# 請完成函式：如果 `year` 是閏年，回傳 `"leap"`；否則回傳 `"normal"`。規則：可以被 400 整除是閏年；可以被 100 整除但不能被 400 整除不是閏年；可以被 4 整除是閏年。
#
# 請完成下面的函式。

# %%
def q4_leap_year(year):
    # TODO: 使用 if / elif / else 判斷閏年
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q4_ok = run_hidden_cases("Q4", q4_leap_year)

# %% [markdown]
# ## Q5. 溫度提醒
#
# 請完成函式：如果 `t >= 35`，回傳 `"very hot"`；如果 `t >= 25`，回傳 `"warm"`；如果 `t >= 10`，回傳 `"cool"`；其他回傳 `"cold"`。
#
# 請完成下面的函式。

# %%
def q5_temperature_message(t):
    # TODO: 依照溫度回傳不同提醒
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q5_ok = run_hidden_cases("Q5", q5_temperature_message)

# %% [markdown]
# ## Q6. 暱稱長度檢查
#
# 請完成函式：如果 `nickname` 長度小於等於 10，回傳 `"ok"`；否則回傳 `"too long"`。提示：可以使用 `len(nickname)`。
#
# 請完成下面的函式。

# %%
def q6_check_nickname(nickname):
    # TODO: 檢查 nickname 長度
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q6_ok = run_hidden_cases("Q6", q6_check_nickname)

# %% [markdown]
# ## Q7. 會員折扣判斷
#
# 請完成函式：如果 `is_member` 是 `True` 且 `total >= 500`，回傳 `"discount"`；否則回傳 `"no discount"`。
#
# 請完成下面的函式。

# %%
def q7_discount(is_member, total):
    # TODO: 需要同時是會員，而且金額達標
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q7_ok = run_hidden_cases("Q7", q7_discount)

# %% [markdown]
# ## Q8. FizzBuzz 簡化版
#
# 請完成函式：如果 `x` 同時是 3 和 5 的倍數，回傳 `"FizzBuzz"`；如果只被 3 整除，回傳 `"Fizz"`；如果只被 5 整除，回傳 `"Buzz"`；其他回傳 `"Other"`。
#
# 請完成下面的函式。

# %%
def q8_fizzbuzz_label(x):
    # TODO: 注意要先判斷同時是 3 和 5 的倍數
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q8_ok = run_hidden_cases("Q8", q8_fizzbuzz_label)

# %% [markdown]
# ## Q9. 紅綠燈行動判斷
#
# 請完成函式：如果 `light` 是 `"green"`，回傳 `"go"`；如果是 `"yellow"`，回傳 `"slow"`；如果是 `"red"`，回傳 `"stop"`；其他回傳 `"unknown"`。
#
# 請完成下面的函式。

# %%
def q9_traffic_light(light):
    # TODO: 依照紅綠燈顏色回傳行動
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q9_ok = run_hidden_cases("Q9", q9_traffic_light)

# %% [markdown]
# ## Q10. 下雨出門提醒
#
# 請完成函式：如果沒有下雨，回傳 `"go out"`；如果有下雨且有雨傘，回傳 `"bring umbrella"`；如果有下雨但沒有雨傘，回傳 `"stay home"`。
#
# 請完成下面的函式。

# %%
def q10_rain_message(is_raining, has_umbrella):
    # TODO: 先判斷是否下雨，再判斷是否有雨傘
    return None

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q10_ok = run_hidden_cases("Q10", q10_rain_message)

# %% [markdown]
# ## 總檢查
#
# 完成所有題目後，執行下面這個 cell。

# %%
final_check([q1_ok, q2_ok, q3_ok, q4_ok, q5_ok, q6_ok, q7_ok, q8_ok, q9_ok, q10_ok])
